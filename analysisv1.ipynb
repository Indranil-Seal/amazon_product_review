# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# 'D:\\Data & Projects\\Amazon Product Review Data'

# %%
amadata = pd.read_csv('7817_1.csv')
amadata.head(5)
# Out:
#                      id       asins   brand                  categories  \
# 0  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 1  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 2  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 3  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
# 4  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon  Amazon Devices,mazon.co.uk
#
#   colors             dateAdded           dateUpdated  \
# 0    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 1    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 2    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 3    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
# 4    NaN  2016-03-08T20:21:53Z  2017-07-18T23:52:58Z
#
#                   dimension  ean                         keys  ...  \
# 0  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# 1  169 mm x 117 mm x 9.1 mm  NaN  kindlepaperwhite/b00qjdu3ky  ...
# ...

# %%
amadata.dtypes
# Out:
# id                       object
# asins                    object
# brand                    object
# categories               object
# colors                   object
# dateAdded                object
# dateUpdated              object
# dimension                object
# ean                     float64
# keys                     object
# manufacturer             object
# manufacturerNumber       object
# name                     object
# prices                   object
# reviews.date             object
# reviews.doRecommend      object
# reviews.numHelpful      float64
# reviews.rating          float64
# reviews.sourceURLs       object
# reviews.text             object
# reviews.title            object
# reviews.userCity        float64
# reviews.userProvince    float64
# reviews.username         object
# sizes                   float64
# upc                     float64
# weight                   object
# dtype: object

# %%
col_list = list(amadata.columns)
datastr = pd.DataFrame(columns = ['colname','obs','uniques','missing_','dtype'])
for col in col_list:
    datum = pd.DataFrame({'colname':[col],
                          'obs':[len(amadata[col])],
                          'uniques':[len(amadata[col].unique())],
                          'missing_':[((amadata[col].isna().sum())/amadata.shape[0])*100],
                          'dtype':[amadata[col].dtype]})
    datastr = pd.concat([datastr,datum],axis = 0)

# %%
datastr
# Out:
#                 colname   obs uniques    missing_    dtype
# 0                    id  1597      66    0.000000   object
# 0                 asins  1597      54    0.000000   object
# 0                 brand  1597       2    0.000000   object
# 0            categories  1597      19    0.000000   object
# 0                colors  1597       4   51.534126   object
# 0             dateAdded  1597      50    0.000000   object
# 0           dateUpdated  1597      42    0.000000   object
# 0             dimension  1597       3   64.621165   object
# 0                   ean  1597       3   43.769568  float64
# 0                  keys  1597      66    0.000000   object
# 0          manufacturer  1597       3   39.574202   object
# 0    manufacturerNumber  1597       7   43.519098   object
# 0                  name  1597      62    0.000000   object
# 0                prices  1597      66    0.000000   object
# 0          reviews.date  1597     383   23.794615   object
# ...

# %% [markdown]
# 1. Investigate the Primary Key
# 2. Investigate the missing information

# %%
amadata.colors.unique()
# Out:
# array([nan, 'GB', 'Black', 'Clear'], dtype=object)

# %%
amadata.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'dateAdded',
#        'dateUpdated', 'dimension', 'ean', 'keys', 'manufacturer',
#        'manufacturerNumber', 'name', 'prices', 'reviews.date',
#        'reviews.doRecommend', 'reviews.numHelpful', 'reviews.rating',
#        'reviews.sourceURLs', 'reviews.text', 'reviews.title',
#        'reviews.userCity', 'reviews.userProvince', 'reviews.username', 'sizes',
#        'upc', 'weight'],
#       dtype='object')

# %%
amadata['brand_cat_key'] = amadata['brand'].astype(str) +"-"+amadata['categories'].astype(str)
brand_cat_list = list(amadata['brand_cat_key'].unique())

# %%
len(brand_cat_list)
# Out:
# 19

# %%
colorsdata = pd.DataFrame()
for brandcat in brand_cat_list:
    datum = pd.DataFrame({'brand_category':brandcat,
                          'colors': amadata.loc[amadata['brand_cat_key'] == brandcat].colors.unique(),
                          '#missing':amadata.loc[amadata['brand_cat_key'] == brandcat].colors.isna().sum()})
    colorsdata = pd.concat([colorsdata,datum],axis = 0)

# %%
colorsdata.loc[(colorsdata['colors'].isna()) == False]
# Out:
#                                       brand_category colors  #missing
# 1                  Amazon-Electronics,Amazon Devices     GB        24
# 0  Amazon-Amazon Devices,Home,Smart Home & Connec...  Black         0
# 0  Moshi-Cell Phones & Accessories,Accessories,Sc...  Clear         0
# 0  Amazon-Amazon Devices,Corded Headsets,Electron...  Black         0

# %%
colorsdata.colors.unique()
# Out:
# array([nan, 'GB', 'Black', 'Clear'], dtype=object)
